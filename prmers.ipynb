# %% [markdown]
# <center>
#   <img src="https://www.mersenne.org/images/Mersenne_Color_80x101.jpg" height="80"/>
#   <img src="https://www.mersenne.org/images/logo.gif" height="80"/>
# </center>
#
# # 🚀 PrMers — GPU-Accelerated Mersenne Prime Testing
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](
# https://colab.research.google.com/github/cherubrock-seb/PrMers/blob/main/prmers.ipynb)
#
# 📌 *This notebook can be run in Google Colab with GPU acceleration.*
# Make sure GPU is enabled: `Runtime > Change runtime type > GPU`
#
# **PrMers** is a high-performance tool for testing Mersenne numbers of the form \( 2^p - 1 \), using **Lucas-Lehmer** and **PRP (Probable Prime)** algorithms on your GPU via OpenCL.
#
# It leverages advanced Number Theoretic Transforms (NTT) and integer-based DWTs to perform extremely fast primality tests.
#
# ---
#
# ### 🎯 How to Use This Notebook
#
# - Use the `exponent_to_test` field below to choose the Mersenne exponent \( p \) you want to test.
# - The program will automatically select **PRP mode** for known exponents and compute the result on your GPU.
#
# ---
#
# ### ⚠️ Important: Enable GPU in Colab
#
# To use PrMers, your runtime must have GPU enabled (e.g., T4 or better):
#
# 1. Go to **Runtime > Change runtime type**.
# 2. Set **Hardware accelerator** to `GPU`.
# 3. Click **Save**.
#
# You can verify your GPU with:
#
# ```python
# !nvidia-smi

# %%
exponent_to_test = 110503  # @param { "type": "number" }

import subprocess
import os

def check_gpu():
    try:
        subprocess.check_output(['nvidia-smi'], stderr=subprocess.STDOUT)
        print("✅ GPU detected and ready!")
    except Exception:
        from IPython.display import Markdown, display
        display(Markdown("""
❌ **GPU not detected.**

To enable GPU in Colab:

1. Click on the top menu: `Runtime` → `Change runtime type`
2. Select `GPU` under *Hardware accelerator*
3. Click `Save`
4. Then re-run the notebook from the beginning (**Runtime > Run all**)

⚠️ Until a GPU is enabled, PrMers cannot run correctly.
"""))
        raise RuntimeError("Execution stopped: GPU not available.")

check_gpu()

# Install Git + clone
# !apt-get install git -y > /dev/null 2>&1
# !git clone https://github.com/cherubrock-seb/PrMers.git
# %cd PrMers
# !make
print("✅ Build OK!")

# NVIDIA driver install (only if not done already)
if not os.path.exists("/content/.nvidia_installed"):
    print("🧹 Removing existing NVIDIA drivers (this may take a few minutes ⏳)...")
    # !sudo apt update -qq > /dev/null
    # !sudo apt purge '*nvidia*' -y > /dev/null 2>&1
    # !sudo DEBIAN_FRONTEND=noninteractive apt update -qq > /dev/null
    # !sudo DEBIAN_FRONTEND=noninteractive apt purge '*nvidia*' -y > /dev/null 2>&1

    print("📦 Installing NVIDIA driver 530... (this may take a few minutes ⏳)")
    # !sudo DEBIAN_FRONTEND=noninteractive apt install nvidia-driver-530 -y > /dev/null 2>&1

    # Create sentinel file
    with open("/content/.nvidia_installed", "w") as f:
        f.write("ok")
    print("✅ NVIDIA driver installed.")
else:
    print("✅ NVIDIA driver already installed — skipping reinstall.")

# Run PrMers
print(f"🚀 Launching PrMers with exponent {exponent_to_test}")
# !./prmers {exponent_to_test} --noaskn
# Out:
# ✅ GPU detected and ready!
# Cloning into 'PrMers'...
# remote: Enumerating objects: 1961, done.
# remote: Counting objects: 100% (141/141), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 1961 (delta 90), reused 87 (delta 48), pack-reused 1820 (from 2)
# Receiving objects: 100% (1961/1961), 56.50 MiB | 33.21 MiB/s, done.
# Resolving deltas: 100% (1209/1209), done.
# /content/PrMers
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/io/JsonBuilder.cpp -o src/io/JsonBuilder.o
# In file included from /usr/include/CL/cl.h:20,
#                  from include/io/JsonBuilder.hpp:8,
#                  from src/io/JsonBuilder.cpp:22:
# /usr/include/CL/cl_version.h:22:104: note: ‘#pragma message: cl_version.h: CL_TARGET_OPENCL_VERSION is not defined. Defaulting to 300 (OpenCL 3.0)’
#    22 | #pragma message("cl_version.h: CL_TARGET_OPENCL_VERSION is not defined. Defaulting to 300 (OpenCL 3.0)")
#       |                                                                                                        ^
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/io/CliParser.cpp -o src/io/CliParser.o
# In file included from /usr/include/CL/cl.h:20,
#                  from include/opencl/Context.hpp:6,
#                  from src/io/CliParser.cpp:29:
# /usr/include/CL/cl_version.h:22:104: note: ‘#pragma message: cl_version.h: CL_TARGET_OPENCL_VERSION is not defined. Defaulting to 300 (OpenCL 3.0)’
#    22 | #pragma message("cl_version.h: CL_TARGET_OPENCL_VERSION is not defined. Defaulting to 300 (OpenCL 3.0)")
#       |                                                                                                        ^
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/io/CurlClient.cpp -o src/io/CurlClient.o
# src/io/CurlClient.cpp: In static member function ‘static std::string io::CurlClient::promptHiddenPassword()’:
# src/io/CurlClient.cpp:40:11: warning: ignoring return value of ‘int system(const char*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#    40 |     system("stty -echo");
#       |     ~~~~~~^~~~~~~~~~~~~~
# src/io/CurlClient.cpp:42:11: warning: ignoring return value of ‘int system(const char*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#    42 |     system("stty echo");
#       |     ~~~~~~^~~~~~~~~~~~~
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/io/WorktodoManager.cpp -o src/io/WorktodoManager.o
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/io/md5.cpp -o src/io/md5.o
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/io/WorktodoParser.cpp -o src/io/WorktodoParser.o
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/io/common.cpp -o src/io/common.o
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/io/sha3.cpp -o src/io/sha3.o
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/util/Color.cpp -o src/util/Color.o
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/util/Fs.cpp -o src/util/Fs.o
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/util/PathUtils.cpp -o src/util/PathUtils.o
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/util/Timer.cpp -o src/util/Timer.o
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/util/OpenCLError.cpp -o src/util/OpenCLError.o
# In file included from /usr/include/CL/cl.h:20,
#                  from include/util/OpenCLError.hpp:7,
#                  from src/util/OpenCLError.cpp:22:
# /usr/include/CL/cl_version.h:22:104: note: ‘#pragma message: cl_version.h: CL_TARGET_OPENCL_VERSION is not defined. Defaulting to 300 (OpenCL 3.0)’
#    22 | #pragma message("cl_version.h: CL_TARGET_OPENCL_VERSION is not defined. Defaulting to 300 (OpenCL 3.0)")
#       |                                                                                                        ^
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/util/Crc32.cpp -o src/util/Crc32.o
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/core/QuickChecker.cpp -o src/core/QuickChecker.o
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/core/Printer.cpp -o src/core/Printer.o
# In file included from /usr/include/CL/cl.h:20,
#                  from include/io/JsonBuilder.hpp:8,
#                  from src/core/Printer.cpp:23:
# /usr/include/CL/cl_version.h:22:104: note: ‘#pragma message: cl_version.h: CL_TARGET_OPENCL_VERSION is not defined. Defaulting to 300 (OpenCL 3.0)’
#    22 | #pragma message("cl_version.h: CL_TARGET_OPENCL_VERSION is not defined. Defaulting to 300 (OpenCL 3.0)")
#       |                                                                                                        ^
# src/core/Printer.cpp: In static member function ‘static bool core::Printer::finalReport(const io::CliOptions&, const std::vector<long unsigned int>&, std::string, uint64_t, const string&, double, std::string)’:
# src/core/Printer.cpp:52:16: warning: unused variable ‘proof’ [-Wunused-variable]
#    52 |     const bool proof = opts.proof;
#       |                ^~~~~
# src/core/Printer.cpp:53:24: warning: unused variable ‘proofFile’ [-Wunused-variable]
#    53 |     const std::string& proofFile = opts.proofFile;
#       |                        ^~~~~~~~~
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/core/Logger.cpp -o src/core/Logger.o
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/core/ProofManager.cpp -o src/core/ProofManager.o
# In file included from /usr/include/CL/cl.h:20,
#                  from include/core/ProofManager.hpp:7,
#                  from src/core/ProofManager.cpp:23:
# /usr/include/CL/cl_version.h:22:104: note: ‘#pragma message: cl_version.h: CL_TARGET_OPENCL_VERSION is not defined. Defaulting to 300 (OpenCL 3.0)’
#    22 | #pragma message("cl_version.h: CL_TARGET_OPENCL_VERSION is not defined. Defaulting to 300 (OpenCL 3.0)")
#       |                                                                                                        ^
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/core/ProofSet.cpp -o src/core/ProofSet.o
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/core/Spinner.cpp -o src/core/Spinner.o
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/core/App.cpp -o src/core/App.o
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/core/BackupManager.cpp -o src/core/BackupManager.o
# In file included from /usr/include/CL/cl.h:20,
#                  from include/core/BackupManager.hpp:7,
#                  from src/core/BackupManager.cpp:23:
# /usr/include/CL/cl_version.h:22:104: note: ‘#pragma message: cl_version.h: CL_TARGET_OPENCL_VERSION is not defined. Defaulting to 300 (OpenCL 3.0)’
#    22 | #pragma message("cl_version.h: CL_TARGET_OPENCL_VERSION is not defined. Defaulting to 300 (OpenCL 3.0)")
#       |                                                                                                        ^
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/opencl/Buffers.cpp -o src/opencl/Buffers.o
# In file included from /usr/include/CL/cl.h:20,
#                  from include/opencl/Buffers.hpp:6,
#                  from src/opencl/Buffers.cpp:22:
# /usr/include/CL/cl_version.h:22:104: note: ‘#pragma message: cl_version.h: CL_TARGET_OPENCL_VERSION is not defined. Defaulting to 300 (OpenCL 3.0)’
#    22 | #pragma message("cl_version.h: CL_TARGET_OPENCL_VERSION is not defined. Defaulting to 300 (OpenCL 3.0)")
#       |                                                                                                        ^
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/opencl/Kernels.cpp -o src/opencl/Kernels.o
# In file included from /usr/include/CL/cl.h:20,
#                  from include/opencl/Kernels.hpp:5,
#                  from src/opencl/Kernels.cpp:22:
# /usr/include/CL/cl_version.h:22:104: note: ‘#pragma message: cl_version.h: CL_TARGET_OPENCL_VERSION is not defined. Defaulting to 300 (OpenCL 3.0)’
#    22 | #pragma message("cl_version.h: CL_TARGET_OPENCL_VERSION is not defined. Defaulting to 300 (OpenCL 3.0)")
#       |                                                                                                        ^
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/opencl/Context.cpp -o src/opencl/Context.o
# src/opencl/Context.cpp:234:22: warning: integer constant is so large that it is unsigned
#   234 |     if(queueSize_ == 18446744073709551615){
#       |                      ^~~~~~~~~~~~~~~~~~~~
# In file included from /usr/include/CL/cl.h:20,
#                  from include/opencl/Context.hpp:6,
#                  from src/opencl/Context.cpp:22:
# /usr/include/CL/cl_version.h:22:104: note: ‘#pragma message: cl_version.h: CL_TARGET_OPENCL_VERSION is not defined. Defaulting to 300 (OpenCL 3.0)’
#    22 | #pragma message("cl_version.h: CL_TARGET_OPENCL_VERSION is not defined. Defaulting to 300 (OpenCL 3.0)")
#       |                                                                                                        ^
# src/opencl/Context.cpp: In member function ‘void opencl::Context::createQueue(std::size_t)’:
# src/opencl/Context.cpp:194:38: warning: ‘_cl_command_queue* clCreateCommandQueue(cl_context, cl_device_id, cl_command_queue_properties, cl_int*)’ is deprecated [-Wdeprecated-declarations]
#   194 |         queue_ = clCreateCommandQueue(context_, device_, 0, &err);
#       |                  ~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from include/opencl/Context.hpp:6,
#                  from src/opencl/Context.cpp:22:
# /usr/include/CL/cl.h:1906:1: note: declared here
#  1906 | clCreateCommandQueue(cl_context                     context,
#       | ^~~~~~~~~~~~~~~~~~~~
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/opencl/Program.cpp -o src/opencl/Program.o
# In file included from /usr/include/CL/cl.h:20,
#                  from src/opencl/Program.cpp:32:
# /usr/include/CL/cl_version.h:22:104: note: ‘#pragma message: cl_version.h: CL_TARGET_OPENCL_VERSION is not defined. Defaulting to 300 (OpenCL 3.0)’
#    22 | #pragma message("cl_version.h: CL_TARGET_OPENCL_VERSION is not defined. Defaulting to 300 (OpenCL 3.0)")
#       |                                                                                                        ^
# In file included from src/opencl/Program.cpp:35:
# include/opencl/Program.hpp: In constructor ‘opencl::Program::Program(const opencl::Context&, cl_device_id, const string&, const string&)’:
# include/opencl/Program.hpp:26:31: warning: ‘opencl::Program::context_’ will be initialized after [-Wreorder]
#    26 |     const opencl::Context&    context_;
#       |                               ^~~~~~~~
# include/opencl/Program.hpp:25:16: warning:   ‘_cl_program* opencl::Program::program_’ [-Wreorder]
#    25 |     cl_program program_;
#       |                ^~~~~~~~
# src/opencl/Program.cpp:47:1: warning:   when initialized here [-Wreorder]
#    47 | Program::Program(const opencl::Context& context, cl_device_id device,
#       | ^~~~~~~
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/opencl/NttEngine.cpp -o src/opencl/NttEngine.o
# In file included from /usr/include/CL/cl.h:20,
#                  from include/opencl/NttEngine.hpp:6,
#                  from src/opencl/NttEngine.cpp:23:
# /usr/include/CL/cl_version.h:22:104: note: ‘#pragma message: cl_version.h: CL_TARGET_OPENCL_VERSION is not defined. Defaulting to 300 (OpenCL 3.0)’
#    22 | #pragma message("cl_version.h: CL_TARGET_OPENCL_VERSION is not defined. Defaulting to 300 (OpenCL 3.0)")
#       |                                                                                                        ^
# src/opencl/NttEngine.cpp: In member function ‘int opencl::NttEngine::forward(cl_mem, uint64_t)’:
# src/opencl/NttEngine.cpp:108:13: warning: unused variable ‘maxLocalMem’ [-Wunused-variable]
#   108 |     cl_uint maxLocalMem=ctx_.getLocalMemSize();
#       |             ^~~~~~~~~~~
# src/opencl/NttEngine.cpp:109:10: warning: unused variable ‘_even_exponent’ [-Wunused-variable]
#   109 |     bool _even_exponent=ctx_.isEvenExponent();
#       |          ^~~~~~~~~~~~~~
# src/opencl/NttEngine.cpp: In member function ‘int opencl::NttEngine::forward_simple(cl_mem, uint64_t)’:
# src/opencl/NttEngine.cpp:267:15: warning: unused variable ‘kernel_radix4_radix2_square_radix2_radix4’ [-Wunused-variable]
#   267 |     cl_kernel kernel_radix4_radix2_square_radix2_radix4 = kernels_.getKernel("kernel_ntt_radix4_radix2_square_radix2_radix4");
#       |               ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# src/opencl/NttEngine.cpp:270:12: warning: unused variable ‘buf_wi’ [-Wunused-variable]
#   270 |     cl_mem buf_wi = buffers_.invTwiddleBuf;
#       |            ^~~~~~
# src/opencl/NttEngine.cpp:275:12: warning: unused variable ‘localSize3’ [-Wunused-variable]
#   275 |     size_t localSize3 = ctx_.getLocalSize3();;
#       |            ^~~~~~~~~~
# src/opencl/NttEngine.cpp:277:13: warning: unused variable ‘maxLocalMem’ [-Wunused-variable]
#   277 |     cl_uint maxLocalMem=ctx_.getLocalMemSize();
#       |             ^~~~~~~~~~~
# src/opencl/NttEngine.cpp:278:10: warning: unused variable ‘_even_exponent’ [-Wunused-variable]
#   278 |     bool _even_exponent=ctx_.isEvenExponent();
#       |          ^~~~~~~~~~~~~~
# src/opencl/NttEngine.cpp: In member function ‘int opencl::NttEngine::inverse(cl_mem, uint64_t)’:
# src/opencl/NttEngine.cpp:425:12: warning: unused variable ‘localSize3’ [-Wunused-variable]
#   425 |     size_t localSize3 = ctx_.getLocalSize3();;
#       |            ^~~~~~~~~~
# src/opencl/NttEngine.cpp:427:13: warning: unused variable ‘maxLocalMem’ [-Wunused-variable]
#   427 |     cl_uint maxLocalMem=ctx_.getLocalMemSize();
#       |             ^~~~~~~~~~~
# src/opencl/NttEngine.cpp: In member function ‘int opencl::NttEngine::inverse_simple(cl_mem, uint64_t)’:
# src/opencl/NttEngine.cpp:526:12: warning: unused variable ‘localSize3’ [-Wunused-variable]
#   526 |     size_t localSize3 = ctx_.getLocalSize3();;
#       |            ^~~~~~~~~~
# src/opencl/NttEngine.cpp:528:13: warning: unused variable ‘maxLocalMem’ [-Wunused-variable]
#   528 |     cl_uint maxLocalMem=ctx_.getLocalMemSize();
#       |             ^~~~~~~~~~~
# src/opencl/NttEngine.cpp:529:10: warning: unused variable ‘_even_exponent’ [-Wunused-variable]
#   529 |     bool _even_exponent=ctx_.isEvenExponent();
#       |          ^~~~~~~~~~~~~~
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/main.cpp -o src/main.o
# In file included from /usr/include/CL/cl.h:20,
#                  from include/opencl/Context.hpp:6,
#                  from include/core/App.hpp:6,
#                  from src/main.cpp:22:
# /usr/include/CL/cl_version.h:22:104: note: ‘#pragma message: cl_version.h: CL_TARGET_OPENCL_VERSION is not defined. Defaulting to 300 (OpenCL 3.0)’
#    22 | #pragma message("cl_version.h: CL_TARGET_OPENCL_VERSION is not defined. Defaulting to 300 (OpenCL 3.0)")
#       |                                                                                                        ^
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/math/GerbiczLiChecker.cpp -o src/math/GerbiczLiChecker.o
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/math/Mod64.cpp -o src/math/Mod64.o
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/math/Carry.cpp -o src/math/Carry.o
# In file included from /usr/include/CL/cl.h:20,
#                  from include/math/Carry.hpp:7,
#                  from src/math/Carry.cpp:23:
# /usr/include/CL/cl_version.h:22:104: note: ‘#pragma message: cl_version.h: CL_TARGET_OPENCL_VERSION is not defined. Defaulting to 300 (OpenCL 3.0)’
#    22 | #pragma message("cl_version.h: CL_TARGET_OPENCL_VERSION is not defined. Defaulting to 300 (OpenCL 3.0)")
#       |                                                                                                        ^
# src/math/Carry.cpp: In member function ‘void math::Carry::handleFinalCarry(std::vector<long unsigned int>&, const std::vector<int>&)’:
# src/math/Carry.cpp:154:27: warning: comparison of integer expressions of different signedness: ‘cl_uint’ {aka ‘unsigned int’} and ‘int’ [-Wsign-compare]
#   154 |     for (cl_uint k = 0; k < n; ++k) {
#       |                         ~~^~~
# src/math/Carry.cpp:159:31: warning: comparison of integer expressions of different signedness: ‘cl_uint’ {aka ‘unsigned int’} and ‘int’ [-Wsign-compare]
#   159 |         for (cl_uint k = 0; k < n; ++k) {
#       |                             ~~^~~
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" -c src/math/Precompute.cpp -o src/math/Precompute.o
# g++ -std=c++20 -O3 -Wall -Iinclude -DHAS_CURL=1 -DKERNEL_PATH=\"/usr/local/share/prmers/\" src/io/JsonBuilder.o src/io/CliParser.o src/io/CurlClient.o src/io/WorktodoManager.o src/io/md5.o src/io/WorktodoParser.o src/io/common.o src/io/sha3.o src/util/Color.o src/util/Fs.o src/util/PathUtils.o src/util/Timer.o src/util/OpenCLError.o src/util/Crc32.o src/core/QuickChecker.o src/core/Printer.o src/core/Logger.o src/core/ProofManager.o src/core/ProofSet.o src/core/Spinner.o src/core/App.o src/core/BackupManager.o src/opencl/Buffers.o src/opencl/Kernels.o src/opencl/Context.o src/opencl/Program.o src/opencl/NttEngine.o src/main.o src/math/GerbiczLiChecker.o src/math/Mod64.o src/math/Carry.o src/math/Precompute.o -o prmers -lOpenCL -lcurl
# ✅ Build OK!
# 🧹 Removing existing NVIDIA drivers (this may take a few minutes ⏳)...
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# 📦 Installing NVIDIA driver 530... (this may take a few minutes ⏳)
# ✅ NVIDIA driver installed.
# 🚀 Launching PrMers with exponent 110503
# Warning: Unknown option '--noaskn'
# Cannot open worktodo.txt
# GPU Vendor: NVIDIA CORPORATION
# Queue size = 0
# Max CL_DEVICE_MAX_WORK_GROUP_SIZE = 1024
# Max CL_DEVICE_MAX_WORK_ITEM_SIZES = 1024, 1024, 64
# Max CL_DEVICE_LOCAL_MEM_SIZE = 49152 bytes
# Transform Size = 8192
# Cannot open worktodo.txt
# Building OpenCL program with options:  -DWG_SIZE=32 -DLOCAL_PROPAGATION_DEPTH=8 -DCARRY_WORKER=1024 -DLOCAL_PROPAGATION_DEPTH_DIV4=2 -DLOCAL_PROPAGATION_DEPTH_DIV4_MIN=1 -DLOCAL_PROPAGATION_DEPTH_DIV2=2 -DLOCAL_PROPAGATION_DEPTH_DIV2_MIN=3 -DWORKER_NTT=2048 -DWORKER_NTT_2_STEPS=512 -DMODULUS_P=110503 -DTRANSFORM_SIZE_N=8192 -DLOCAL_SIZE=256 -DLOCAL_SIZE2=256 -DLOCAL_SIZE3=256
# OpenCL program built successfully from: /content/PrMers/kernels/prmers.cl
# PrMers : GPU‐accelerated Mersenne primality test (OpenCL, NTT, Lucas Lehmer)
# Testing exponent : 110503
# Device OpenCL ID : 0
# Mode : PRP
# Backup interval : 3000 s
# Save/Load path: .
# Looking for loop file at "/content/PrMers/./110503prp.loop"
# No valid loop file, initializing fresh state
# Initial x[0] set to 3 (PRP mode)
# Progress: 0.00% | Exp: 110503 | Iter: 0 | Elapsed: 0.00s | IPS: 0.00 | ETA: 0d 0h 0m 0s
# Iter: 100000 | Res64: B054C0135811026A
# Progress: 100.00% | Exp: 110503 | Iter: 110503 | Elapsed: 6.42s | IPS: 17208.14 | ETA: 0d 0h 0m 0s | RES64: 0000000000000001
#
# State saved to ./110503prp.mers
# Loop iteration saved to ./110503prp.loop
#
# Warning: Cannot open file for MD5:
#
# M110503 PRP test: probably prime (residue is 9).
#
# Manual submission JSON:
# {"status":"P","exponent":110503,"worktype":"PRP-3","res64":"0000000000000001","res2048":"...","residue-type":1,"errors":{"gerbicz":0},"fft-length":8192,"shift-count":0,"program":{"name":"prmers","version":"0.1.0","port":8},"os":{"os":"Linux","architecture":"x86_64"},"user":"cherubrock","timestamp":"2025-05-03 07:42:12","checksum":{"version":1,"checksum":"BA99D5D0"}}
#
# Total elapsed time: 6.42 seconds.
# Do you want to send the result to PrimeNet (https://www.mersenne.org) ? (y/n): n
# Result not sent.
# Removed backup file: ./110503prp.mers
# Removed loop file: ./110503prp.loop
# JSON result written to: ./110503_prp_result.json
# Result appended to: ./results.txt

# %%
#Example with a prime mersenne number
# !make
# !./prmers 74207281 -prp -f
# Out:
# ❌ Cannot open file: "worktodo.txt"
# ✅ No valid task found in "worktodo.txt".
# 🧮 Testing exponent: 859433
# Warning: Ignoring unexpected argument '859433'
# PrMers: GPU-accelerated Mersenne primality test (OpenCL, NTT, Lucas-Lehmer)
# Testing exponent: 859433
# Using OpenCL device ID: 0
# Mode selected: PRP
# Backup interval: 120 seconds
# Save/Load path: .
# OpenCL device version detected: 3.0
# Max CL_DEVICE_MAX_WORK_GROUP_SIZE = 1024
# Max CL_DEVICE_MAX_WORK_ITEM_SIZES = 0
# Max CL_DEVICE_LOCAL_MEM_SIZE = 0
# Max max_digit_width for IBDWT = 14
#
# Launching OpenCL kernel (p = 859433); computation may take a while.
# Transform size: 65536
# Final workers count: 65536
# Work-groups count: 256
# Work-groups size: 256
# Workers for carry propagation count: 8192
# Local carry propagation depht: 8
# Local size carry: 256
# Proof Power : 8
# Building OpenCL program with options:  -DWG_SIZE=256 -DLOCAL_PROPAGATION_DEPTH=8 -DCARRY_WORKER=8192 -DLOCAL_PROPAGATION_DEPTH_DIV4=2 -DLOCAL_PROPAGATION_DEPTH_DIV4_MIN=1 -DLOCAL_PROPAGATION_DEPTH_DIV2=2 -DLOCAL_PROPAGATION_DEPTH_DIV2_MIN=3 -DWORKER_NTT=16384 -DWORKER_NTT_2_STEPS=4096 -DMODULUS_P=859433 -DTRANSFORM_SIZE_N=65536 -DLOCAL_SIZE=256 -DLOCAL_SIZE2=256 -DLOCAL_SIZE3=256
# Progress: 1.38% | Exponent: 859433 | Iteration: 11829 | Elapsed: 1.00s | Iterations/sec: 11828.72 | ETA: 0d 0h 1m 11s
# Progress: 3.02% | Exponent: 859433 | Iteration: 25975 | Elapsed: 2.00s | Iterations/sec: 12986.89 | ETA: 0d 0h 1m 4s
# Progress: 4.67% | Exponent: 859433 | Iteration: 40094 | Elapsed: 3.00s | Iterations/sec: 13363.79 | ETA: 0d 0h 1m 1s
# Progress: 6.31% | Exponent: 859433 | Iteration: 54210 | Elapsed: 4.00s | Iterations/sec: 13551.56 | ETA: 0d 0h 0m 59s
proof
# Proof is saved in a file!
#
#
# ✅ JSON result written to: ./859433_prp_result.json
#
# =============================================
# 🟢 M859433 PRP TEST PASSED
# ✅ RESULT: PROBABLY PRIME (residue is 9)
# =============================================
# 📦 res64 = 0x0000000000000001
# =============================================

# %%
#Example with a COMPOSITE mersenne numbern
# !./prmers 100003 --noask
# Out:
# ❌ Cannot open file: "worktodo.txt"
# ✅ No valid task found in "worktodo.txt".
# 🧮 Testing exponent: 100003
# Warning: Ignoring unexpected argument '100003'
# PrMers: GPU-accelerated Mersenne primality test (OpenCL, NTT, Lucas-Lehmer)
# Testing exponent: 100003
# Using OpenCL device ID: 0
# Mode selected: PRP
# Backup interval: 120 seconds
# Save/Load path: .
# OpenCL device version detected: 3.0
# Max CL_DEVICE_MAX_WORK_GROUP_SIZE = 1024
# Max CL_DEVICE_MAX_WORK_ITEM_SIZES = 0
# Max CL_DEVICE_LOCAL_MEM_SIZE = 0
# Max max_digit_width for IBDWT = 25
#
# Launching OpenCL kernel (p = 100003); computation may take a while.
# Transform size: 4096
# Final workers count: 4096
# Work-groups count: 256
# Work-groups size: 16
# Workers for carry propagation count: 512
# Local carry propagation depht: 8
# Local size carry: 256
# Proof Power : 6
# Building OpenCL program with options:  -DWG_SIZE=16 -DLOCAL_PROPAGATION_DEPTH=8 -DCARRY_WORKER=512 -DLOCAL_PROPAGATION_DEPTH_DIV4=2 -DLOCAL_PROPAGATION_DEPTH_DIV4_MIN=1 -DLOCAL_PROPAGATION_DEPTH_DIV2=2 -DLOCAL_PROPAGATION_DEPTH_DIV2_MIN=3 -DWORKER_NTT=1024 -DWORKER_NTT_2_STEPS=256 -DMODULUS_P=100003 -DTRANSFORM_SIZE_N=4096 -DLOCAL_SIZE=256 -DLOCAL_SIZE2=256 -DLOCAL_SIZE3=256
# Progress: 17.40% | Exponent: 100003 | Iteration: 17398 | Elapsed: 1.00s | Iterations/sec: 17397.20 | ETA: 0d 0h 0m 4s
# Progress: 38.43% | Exponent: 100003 | Iteration: 38436 | Elapsed: 2.00s | Iterations/sec: 19216.79 | ETA: 0d 0h 0m 3s
# Progress: 58.19% | Exponent: 100003 | Iteration: 58191 | Elapsed: 3.00s | Iterations/sec: 19395.56 | ETA: 0d 0h 0m 2s
# Progress: 76.10% | Exponent: 100003 | Iteration: 76101 | Elapsed: 4.00s | Iterations/sec: 19020.26 | ETA: 0d 0h 0m 1s
# Progress: 94.96% | Exponent: 100003 | Iteration: 94964 | Elapsed: 5.00s | Iterations/sec: 18988.63 | ETA: 0d 0h 0m 0s
# Progress: 100.00% | Exponent: 100003 | Iteration: 100003 | Elapsed: 5.24s | Iterations/sec: 19084.56 | ETA: 0d 0h 0m 0s
#
# Kernel execution time: 5.24 seconds
# Iterations per second: 19084.41 (100003 iterations in total)
# Proof generation : Saved partial residue at iteration 1563
# Proof generation : Saved partial residue at iteration 3126
# Proof generation : Saved partial residue at iteration 6251
# Proof generation : Saved partial residue at iteration 12501
# Proof generation : Saved partial residue at iteration 25001
# Proof generation : Saved partial residue at iteration 50002
# Proof saved to ./100003-6.proof
# Proof is saved in a file!
#
#
# ✅ JSON result written to: ./100003_prp_result.json
#
# =============================================
# 🔴 M100003 PRP TEST FAILED
# ❌ RESULT: PROBABLY COMPOSITE (residue is not 9)
# =============================================
# 📦 res64 = 0x1CF45E9503C71FD6
# =============================================

# %%
#Example by using worktodo.txt
from sympy import nextprime
exponents = [100003]
current = 100003
for _ in range(5):
    current = nextprime(current + 1)
    exponents.append(current)
aid = "1EA49D835E08995147899AB4A0E90FF1"
lines = [f"PRP={aid},1,2,{p},-1,76,2" for p in exponents]
with open("worktodo.txt", "w") as f:
    f.write("\n".join(lines))
print("✅ worktodo.txt generated with the following contents:\n")
print("\n".join(lines))

# !./prmers
# !cat results.txt
# Out:
# ✅ worktodo.txt generated with the following contents:
#
# PRP=1EA49D835E08995147899AB4A0E90FF1,1,2,100003,-1,76,2
# PRP=1EA49D835E08995147899AB4A0E90FF1,1,2,100019,-1,76,2
# PRP=1EA49D835E08995147899AB4A0E90FF1,1,2,100043,-1,76,2
# PRP=1EA49D835E08995147899AB4A0E90FF1,1,2,100049,-1,76,2
# PRP=1EA49D835E08995147899AB4A0E90FF1,1,2,100057,-1,76,2
# PRP=1EA49D835E08995147899AB4A0E90FF1,1,2,100069,-1,76,2
# 📄 Line 1: PRP=1EA49D835E08995147899AB4A0E90FF1,1,2,100003,-1,76,2
#    ✅ Valid task: exponent = 100003 (PRP)
# 🧮 Testing exponent: 100003
# Warning: Ignoring unexpected argument '100003'
# PrMers: GPU-accelerated Mersenne primality test (OpenCL, NTT, Lucas-Lehmer)
# Testing exponent: 100003
# Using OpenCL device ID: 0
# Mode selected: PRP
# Backup interval: 120 seconds
# Save/Load path: .
# OpenCL device version detected: 3.0
# Max CL_DEVICE_MAX_WORK_GROUP_SIZE = 1024
# Max CL_DEVICE_MAX_WORK_ITEM_SIZES = 0
# Max CL_DEVICE_LOCAL_MEM_SIZE = 0
# Max max_digit_width for IBDWT = 25
#
# Launching OpenCL kernel (p = 100003); computation may take a while.
# Transform size: 4096
# Final workers count: 4096
# Work-groups count: 256
# Work-groups size: 16
# Workers for carry propagation count: 512
# Local carry propagation depht: 8
# Local size carry: 256
# Proof Power : 6
# Building OpenCL program with options:  -DWG_SIZE=16 -DLOCAL_PROPAGATION_DEPTH=8 -DCARRY_WORKER=512 -DLOCAL_PROPAGATION_DEPTH_DIV4=2 -DLOCAL_PROPAGATION_DEPTH_DIV4_MIN=1 -DLOCAL_PROPAGATION_DEPTH_DIV2=2 -DLOCAL_PROPAGATION_DEPTH_DIV2_MIN=3 -DWORKER_NTT=1024 -DWORKER_NTT_2_STEPS=256 -DMODULUS_P=100003 -DTRANSFORM_SIZE_N=4096 -DLOCAL_SIZE=256 -DLOCAL_SIZE2=256 -DLOCAL_SIZE3=256
# Progress: 18.12% | Exponent: 100003 | Iteration: 18121 | Elapsed: 1.00s | Iterations/sec: 18120.30 | ETA: 0d 0h 0m 4s
# Progress: 39.20% | Exponent: 100003 | Iteration: 39202 | Elapsed: 2.00s | Iterations/sec: 19599.83 | ETA: 0d 0h 0m 3s
# Progress: 60.18% | Exponent: 100003 | Iteration: 60180 | Elapsed: 3.00s | Iterations/sec: 20058.79 | ETA: 0d 0h 0m 1s
# Progress: 81.26% | Exponent: 100003 | Iteration: 81265 | Elapsed: 4.00s | Iterations/sec: 20315.02 | ETA: 0d 0h 0m 0s
# Progress: 100.00% | Exponent: 100003 | Iteration: 100003 | Elapsed: 4.89s | Iterations/sec: 20452.16 | ETA: 0d 0h 0m 0s
#
# Kernel execution time: 4.89 seconds
# Iterations per second: 20451.97 (100003 iterations in total)
# Proof generation : Saved partial residue at iteration 1563
# Proof generation : Saved partial residue at iteration 3126
# Proof generation : Saved partial residue at iteration 6251
# Proof generation : Saved partial residue at iteration 12501
# Proof generation : Saved partial residue at iteration 25001
# Proof generation : Saved partial residue at iteration 50002
# Proof saved to ./100003-6.proof
# Proof is saved in a file!
#
#
# ✅ JSON result written to: ./100003_prp_result.json
#
# =============================================
# 🔴 M100003 PRP TEST FAILED
# ❌ RESULT: PROBABLY COMPOSITE (residue is not 9)
# =============================================
# 📦 res64 = 0x1CF45E9503C71FD6
# =============================================
# → Result added to: ./result.txt
# → Processed entry removed from worktodo.txt and saved to worktodo_save.txt
#
# 🔁 Restarting program without exponent:
#    ./prmers
# 📄 Line 1: PRP=1EA49D835E08995147899AB4A0E90FF1,1,2,100019,-1,76,2
#    ✅ Valid task: exponent = 100019 (PRP)
# 🧮 Testing exponent: 100019
# Warning: Ignoring unexpected argument '100019'
# PrMers: GPU-accelerated Mersenne primality test (OpenCL, NTT, Lucas-Lehmer)
# Testing exponent: 100019
# Using OpenCL device ID: 0
# Mode selected: PRP
# Backup interval: 120 seconds
# Save/Load path: .
# OpenCL device version detected: 3.0
# Max CL_DEVICE_MAX_WORK_GROUP_SIZE = 1024
# Max CL_DEVICE_MAX_WORK_ITEM_SIZES = 0
# Max CL_DEVICE_LOCAL_MEM_SIZE = 0
# Max max_digit_width for IBDWT = 25
#
# Launching OpenCL kernel (p = 100019); computation may take a while.
# Transform size: 4096
# Final workers count: 4096
# Work-groups count: 256
# Work-groups size: 16
# Workers for carry propagation count: 512
# Local carry propagation depht: 8
# Local size carry: 256
# Proof Power : 6
# Building OpenCL program with options:  -DWG_SIZE=16 -DLOCAL_PROPAGATION_DEPTH=8 -DCARRY_WORKER=512 -DLOCAL_PROPAGATION_DEPTH_DIV4=2 -DLOCAL_PROPAGATION_DEPTH_DIV4_MIN=1 -DLOCAL_PROPAGATION_DEPTH_DIV2=2 -DLOCAL_PROPAGATION_DEPTH_DIV2_MIN=3 -DWORKER_NTT=1024 -DWORKER_NTT_2_STEPS=256 -DMODULUS_P=100019 -DTRANSFORM_SIZE_N=4096 -DLOCAL_SIZE=256 -DLOCAL_SIZE2=256 -DLOCAL_SIZE3=256
# Progress: 15.45% | Exponent: 100019 | Iteration: 15457 | Elapsed: 1.00s | Iterations/sec: 15456.51 | ETA: 0d 0h 0m 5s
# Progress: 33.73% | Exponent: 100019 | Iteration: 33734 | Elapsed: 2.00s | Iterations/sec: 16866.17 | ETA: 0d 0h 0m 3s
# Progress: 54.82% | Exponent: 100019 | Iteration: 54829 | Elapsed: 3.00s | Iterations/sec: 18275.44 | ETA: 0d 0h 0m 2s
# Progress: 75.89% | Exponent: 100019 | Iteration: 75908 | Elapsed: 4.00s | Iterations/sec: 18975.96 | ETA: 0d 0h 0m 1s
# Progress: 96.90% | Exponent: 100019 | Iteration: 96916 | Elapsed: 5.00s | Iterations/sec: 19382.19 | ETA: 0d 0h 0m 0s
# Progress: 100.00% | Exponent: 100019 | Iteration: 100019 | Elapsed: 5.15s | Iterations/sec: 19431.49 | ETA: 0d 0h 0m 0s
#
# Kernel execution time: 5.15 seconds
# Iterations per second: 19431.36 (100019 iterations in total)
# Proof generation : Saved partial residue at iteration 1563
# Proof generation : Saved partial residue at iteration 3126
# Proof generation : Saved partial residue at iteration 6252
# Proof generation : Saved partial residue at iteration 12503
# Proof generation : Saved partial residue at iteration 25005
# Proof generation : Saved partial residue at iteration 50010
# Proof saved to ./100019-6.proof
# Proof is saved in a file!
#
#
# ✅ JSON result written to: ./100019_prp_result.json
#
# =============================================
# 🔴 M100019 PRP TEST FAILED
# ❌ RESULT: PROBABLY COMPOSITE (residue is not 9)
# =============================================
# 📦 res64 = 0x0F1401EB99B93CB3
# =============================================
# → Result added to: ./result.txt
# → Processed entry removed from worktodo.txt and saved to worktodo_save.txt
#
# 🔁 Restarting program without exponent:
#    ./prmers
# 📄 Line 1: PRP=1EA49D835E08995147899AB4A0E90FF1,1,2,100043,-1,76,2
#    ✅ Valid task: exponent = 100043 (PRP)
# 🧮 Testing exponent: 100043
# Warning: Ignoring unexpected argument '100043'
# PrMers: GPU-accelerated Mersenne primality test (OpenCL, NTT, Lucas-Lehmer)
# Testing exponent: 100043
# Using OpenCL device ID: 0
# Mode selected: PRP
# Backup interval: 120 seconds
# Save/Load path: .
# OpenCL device version detected: 3.0
# Max CL_DEVICE_MAX_WORK_GROUP_SIZE = 1024
# Max CL_DEVICE_MAX_WORK_ITEM_SIZES = 0
# Max CL_DEVICE_LOCAL_MEM_SIZE = 0
# Max max_digit_width for IBDWT = 25
#
# Launching OpenCL kernel (p = 100043); computation may take a while.
# Transform size: 4096
# Final workers count: 4096
# Work-groups count: 256
# Work-groups size: 16
# Workers for carry propagation count: 512
# Local carry propagation depht: 8
# Local size carry: 256
# Proof Power : 6
# Building OpenCL program with options:  -DWG_SIZE=16 -DLOCAL_PROPAGATION_DEPTH=8 -DCARRY_WORKER=512 -DLOCAL_PROPAGATION_DEPTH_DIV4=2 -DLOCAL_PROPAGATION_DEPTH_DIV4_MIN=1 -DLOCAL_PROPAGATION_DEPTH_DIV2=2 -DLOCAL_PROPAGATION_DEPTH_DIV2_MIN=3 -DWORKER_NTT=1024 -DWORKER_NTT_2_STEPS=256 -DMODULUS_P=100043 -DTRANSFORM_SIZE_N=4096 -DLOCAL_SIZE=256 -DLOCAL_SIZE2=256 -DLOCAL_SIZE3=256
# Progress: 18.02% | Exponent: 100043 | Iteration: 18026 | Elapsed: 1.00s | Iterations/sec: 18025.84 | ETA: 0d 0h 0m 4s
# Progress: 39.10% | Exponent: 100043 | Iteration: 39115 | Elapsed: 2.00s | Iterations/sec: 19556.87 | ETA: 0d 0h 0m 3s
# Progress: 60.18% | Exponent: 100043 | Iteration: 60207 | Elapsed: 3.00s | Iterations/sec: 20068.10 | ETA: 0d 0h 0m 1s
# Progress: 81.26% | Exponent: 100043 | Iteration: 81295 | Elapsed: 4.00s | Iterations/sec: 20322.84 | ETA: 0d 0h 0m 0s
# Progress: 99.69% | Exponent: 100043 | Iteration: 99729 | Elapsed: 5.00s | Iterations/sec: 19944.88 | ETA: 0d 0h 0m 0s
# Progress: 100.00% | Exponent: 100043 | Iteration: 100043 | Elapsed: 5.02s | Iterations/sec: 19936.95 | ETA: 0d 0h 0m 0s
#
# Kernel execution time: 5.02 seconds
# Iterations per second: 19936.82 (100043 iterations in total)
# Proof generation : Saved partial residue at iteration 1564
# Proof generation : Saved partial residue at iteration 3127
# Proof generation : Saved partial residue at iteration 6253
# Proof generation : Saved partial residue at iteration 12506
# Proof generation : Saved partial residue at iteration 25011
# Proof generation : Saved partial residue at iteration 50022
# Proof saved to ./100043-6.proof
# Proof is saved in a file!
#
#
# ✅ JSON result written to: ./100043_prp_result.json
#
# =============================================
# 🔴 M100043 PRP TEST FAILED
# ❌ RESULT: PROBABLY COMPOSITE (residue is not 9)
# =============================================
# 📦 res64 = 0x2D1060D35EBD86DE
# =============================================
# → Result added to: ./result.txt
# → Processed entry removed from worktodo.txt and saved to worktodo_save.txt
#
# 🔁 Restarting program without exponent:
#    ./prmers
# 📄 Line 1: PRP=1EA49D835E08995147899AB4A0E90FF1,1,2,100049,-1,76,2
#    ✅ Valid task: exponent = 100049 (PRP)
# 🧮 Testing exponent: 100049
# Warning: Ignoring unexpected argument '100049'
# PrMers: GPU-accelerated Mersenne primality test (OpenCL, NTT, Lucas-Lehmer)
# Testing exponent: 100049
# Using OpenCL device ID: 0
# Mode selected: PRP
# Backup interval: 120 seconds
# Save/Load path: .
# OpenCL device version detected: 3.0
# Max CL_DEVICE_MAX_WORK_GROUP_SIZE = 1024
# Max CL_DEVICE_MAX_WORK_ITEM_SIZES = 0
# Max CL_DEVICE_LOCAL_MEM_SIZE = 0
# Max max_digit_width for IBDWT = 25
#
# Launching OpenCL kernel (p = 100049); computation may take a while.
# Transform size: 4096
# Final workers count: 4096
# Work-groups count: 256
# Work-groups size: 16
# Workers for carry propagation count: 512
# Local carry propagation depht: 8
# Local size carry: 256
# Proof Power : 6
# Building OpenCL program with options:  -DWG_SIZE=16 -DLOCAL_PROPAGATION_DEPTH=8 -DCARRY_WORKER=512 -DLOCAL_PROPAGATION_DEPTH_DIV4=2 -DLOCAL_PROPAGATION_DEPTH_DIV4_MIN=1 -DLOCAL_PROPAGATION_DEPTH_DIV2=2 -DLOCAL_PROPAGATION_DEPTH_DIV2_MIN=3 -DWORKER_NTT=1024 -DWORKER_NTT_2_STEPS=256 -DMODULUS_P=100049 -DTRANSFORM_SIZE_N=4096 -DLOCAL_SIZE=256 -DLOCAL_SIZE2=256 -DLOCAL_SIZE3=256
# Progress: 18.15% | Exponent: 100049 | Iteration: 18157 | Elapsed: 1.00s | Iterations/sec: 18156.54 | ETA: 0d 0h 0m 4s
# Progress: 39.18% | Exponent: 100049 | Iteration: 39199 | Elapsed: 2.00s | Iterations/sec: 19598.62 | ETA: 0d 0h 0m 3s
# Progress: 60.23% | Exponent: 100049 | Iteration: 60256 | Elapsed: 3.00s | Iterations/sec: 20084.33 | ETA: 0d 0h 0m 1s
# Progress: 81.28% | Exponent: 100049 | Iteration: 81315 | Elapsed: 4.00s | Iterations/sec: 20327.74 | ETA: 0d 0h 0m 0s
# Progress: 100.00% | Exponent: 100049 | Iteration: 100049 | Elapsed: 4.89s | Iterations/sec: 20462.90 | ETA: 0d 0h 0m 0s
#
# Kernel execution time: 4.89 seconds
# Iterations per second: 20462.74 (100049 iterations in total)
# Proof generation : Saved partial residue at iteration 1564
# Proof generation : Saved partial residue at iteration 3127
# Proof generation : Saved partial residue at iteration 6254
# Proof generation : Saved partial residue at iteration 12507
# Proof generation : Saved partial residue at iteration 25013
# Proof generation : Saved partial residue at iteration 50025
# Proof saved to ./100049-6.proof
# Proof is saved in a file!
#
#
# ✅ JSON result written to: ./100049_prp_result.json
#
# =============================================
# 🔴 M100049 PRP TEST FAILED
# ❌ RESULT: PROBABLY COMPOSITE (residue is not 9)
# =============================================
# 📦 res64 = 0x44E92286ACDE5C09
# =============================================
# → Result added to: ./result.txt
# → Processed entry removed from worktodo.txt and saved to worktodo_save.txt
#
# 🔁 Restarting program without exponent:
#    ./prmers
# 📄 Line 1: PRP=1EA49D835E08995147899AB4A0E90FF1,1,2,100057,-1,76,2
#    ✅ Valid task: exponent = 100057 (PRP)
# 🧮 Testing exponent: 100057
# Warning: Ignoring unexpected argument '100057'
# PrMers: GPU-accelerated Mersenne primality test (OpenCL, NTT, Lucas-Lehmer)
# Testing exponent: 100057
# Using OpenCL device ID: 0
# Mode selected: PRP
# Backup interval: 120 seconds
# Save/Load path: .
# OpenCL device version detected: 3.0
# Max CL_DEVICE_MAX_WORK_GROUP_SIZE = 1024
# Max CL_DEVICE_MAX_WORK_ITEM_SIZES = 0
# Max CL_DEVICE_LOCAL_MEM_SIZE = 0
# Max max_digit_width for IBDWT = 25
#
# Launching OpenCL kernel (p = 100057); computation may take a while.
# Transform size: 4096
# Final workers count: 4096
# Work-groups count: 256
# Work-groups size: 16
# Workers for carry propagation count: 512
# Local carry propagation depht: 8
# Local size carry: 256
# Proof Power : 6
# Building OpenCL program with options:  -DWG_SIZE=16 -DLOCAL_PROPAGATION_DEPTH=8 -DCARRY_WORKER=512 -DLOCAL_PROPAGATION_DEPTH_DIV4=2 -DLOCAL_PROPAGATION_DEPTH_DIV4_MIN=1 -DLOCAL_PROPAGATION_DEPTH_DIV2=2 -DLOCAL_PROPAGATION_DEPTH_DIV2_MIN=3 -DWORKER_NTT=1024 -DWORKER_NTT_2_STEPS=256 -DMODULUS_P=100057 -DTRANSFORM_SIZE_N=4096 -DLOCAL_SIZE=256 -DLOCAL_SIZE2=256 -DLOCAL_SIZE3=256
# Progress: 17.93% | Exponent: 100057 | Iteration: 17945 | Elapsed: 1.00s | Iterations/sec: 17944.28 | ETA: 0d 0h 0m 4s
# Progress: 36.10% | Exponent: 100057 | Iteration: 36120 | Elapsed: 2.00s | Iterations/sec: 18059.23 | ETA: 0d 0h 0m 3s
# Progress: 53.82% | Exponent: 100057 | Iteration: 53846 | Elapsed: 3.00s | Iterations/sec: 17947.79 | ETA: 0d 0h 0m 2s
# Progress: 74.12% | Exponent: 100057 | Iteration: 74161 | Elapsed: 4.00s | Iterations/sec: 18539.26 | ETA: 0d 0h 0m 1s
# Progress: 95.25% | Exponent: 100057 | Iteration: 95305 | Elapsed: 5.00s | Iterations/sec: 19059.93 | ETA: 0d 0h 0m 0s
# Progress: 100.00% | Exponent: 100057 | Iteration: 100057 | Elapsed: 5.22s | Iterations/sec: 19149.85 | ETA: 0d 0h 0m 0s
#
# Kernel execution time: 5.22 seconds
# Iterations per second: 19149.74 (100057 iterations in total)
# Proof generation : Saved partial residue at iteration 1564
# Proof generation : Saved partial residue at iteration 3127
# Proof generation : Saved partial residue at iteration 6254
# Proof generation : Saved partial residue at iteration 12508
# Proof generation : Saved partial residue at iteration 25015
# Proof generation : Saved partial residue at iteration 50029
# Proof saved to ./100057-6.proof
# Proof is saved in a file!
#
#
# ✅ JSON result written to: ./100057_prp_result.json
#
# =============================================
# 🔴 M100057 PRP TEST FAILED
# ❌ RESULT: PROBABLY COMPOSITE (residue is not 9)
# =============================================
# 📦 res64 = 0x868629ECF6808FF5
# =============================================
# → Result added to: ./result.txt
# → Processed entry removed from worktodo.txt and saved to worktodo_save.txt
#
# 🔁 Restarting program without exponent:
#    ./prmers
# 📄 Line 1: PRP=1EA49D835E08995147899AB4A0E90FF1,1,2,100069,-1,76,2
#    ✅ Valid task: exponent = 100069 (PRP)
# 🧮 Testing exponent: 100069
# Warning: Ignoring unexpected argument '100069'
# PrMers: GPU-accelerated Mersenne primality test (OpenCL, NTT, Lucas-Lehmer)
# Testing exponent: 100069
# Using OpenCL device ID: 0
# Mode selected: PRP
# Backup interval: 120 seconds
# Save/Load path: .
# OpenCL device version detected: 3.0
# Max CL_DEVICE_MAX_WORK_GROUP_SIZE = 1024
# Max CL_DEVICE_MAX_WORK_ITEM_SIZES = 0
# Max CL_DEVICE_LOCAL_MEM_SIZE = 0
# Max max_digit_width for IBDWT = 25
#
# Launching OpenCL kernel (p = 100069); computation may take a while.
# Transform size: 4096
# Final workers count: 4096
# Work-groups count: 256
# Work-groups size: 16
# Workers for carry propagation count: 512
# Local carry propagation depht: 8
# Local size carry: 256
# Proof Power : 6
# Building OpenCL program with options:  -DWG_SIZE=16 -DLOCAL_PROPAGATION_DEPTH=8 -DCARRY_WORKER=512 -DLOCAL_PROPAGATION_DEPTH_DIV4=2 -DLOCAL_PROPAGATION_DEPTH_DIV4_MIN=1 -DLOCAL_PROPAGATION_DEPTH_DIV2=2 -DLOCAL_PROPAGATION_DEPTH_DIV2_MIN=3 -DWORKER_NTT=1024 -DWORKER_NTT_2_STEPS=256 -DMODULUS_P=100069 -DTRANSFORM_SIZE_N=4096 -DLOCAL_SIZE=256 -DLOCAL_SIZE2=256 -DLOCAL_SIZE3=256
# Progress: 17.90% | Exponent: 100069 | Iteration: 17916 | Elapsed: 1.00s | Iterations/sec: 17915.81 | ETA: 0d 0h 0m 4s
# Progress: 38.91% | Exponent: 100069 | Iteration: 38938 | Elapsed: 2.00s | Iterations/sec: 19468.00 | ETA: 0d 0h 0m 3s
# Progress: 59.92% | Exponent: 100069 | Iteration: 59964 | Elapsed: 3.00s | Iterations/sec: 19987.06 | ETA: 0d 0h 0m 2s
# Progress: 80.91% | Exponent: 100069 | Iteration: 80961 | Elapsed: 4.00s | Iterations/sec: 20239.11 | ETA: 0d 0h 0m 0s
# Progress: 100.00% | Exponent: 100069 | Iteration: 100069 | Elapsed: 4.91s | Iterations/sec: 20376.24 | ETA: 0d 0h 0m 0s
#
# Kernel execution time: 4.91 seconds
# Iterations per second: 20376.09 (100069 iterations in total)
# Proof generation : Saved partial residue at iteration 1564
# Proof generation : Saved partial residue at iteration 3128
# Proof generation : Saved partial residue at iteration 6255
# Proof generation : Saved partial residue at iteration 12509
# Proof generation : Saved partial residue at iteration 25018
# Proof generation : Saved partial residue at iteration 50035
# Proof saved to ./100069-6.proof
# Proof is saved in a file!
#
#
# ✅ JSON result written to: ./100069_prp_result.json
#
# =============================================
# 🔴 M100069 PRP TEST FAILED
# ❌ RESULT: PROBABLY COMPOSITE (residue is not 9)
# =============================================
# 📦 res64 = 0x0EC49AB2F39CBDD2
# =============================================
# → Result added to: ./result.txt
# → Processed entry removed from worktodo.txt and saved to worktodo_save.txt
#
# 🔁 Restarting program without exponent:
#    ./prmers
# ✅ No valid task found in "worktodo.txt".
# {"status":"C", "exponent":100003, "worktype":"PRP-3", "res64":"1CF45E9503C71FD6", "res2048":"...", "residue-type":1, "errors": {"gerbicz":0}, "fft-length":4096, "proof": {"version":1, "power":6, "hashsize":64, "md5":"033430161de8f3d377941b6e61de8b62"}, "program": {"name":"prmers", "version":"0.1", "port":8, "os": {"os":"Linux", "version":"", "architecture":"x86_64"}}, "user":"cherubrock", "aid":"1EA49D835E08995147899AB4A0E90FF1", "uid":"1EA49D835E08995147899AB4A0E90FF1", "timestamp":"2025-04-21 15:27:57"}
# {"status":"C", "exponent":100019, "worktype":"PRP-3", "res64":"0F1401EB99B93CB3", "res2048":"...", "residue-type":1, "errors": {"gerbicz":0}, "fft-length":4096, "proof": {"version":1, "power":6, "hashsize":64, "md5":"9f316540e271f0d013acb2ef3f4a992f"}, "program": {"name":"prmers", "version":"0.1", "port":8, "os": {"os":"Linux", "version":"", "architecture":"x86_64"}}, "user":"cherubrock", "aid":"1EA49D835E08995147899AB4A0E90FF1", "uid":"1EA49D835E08995147899AB4A0E90FF1", "timestamp":"2025-04-21 15:28:05"}
# {"status":"C", "exponent":100043, "worktype":"PRP-3", "res64":"2D1060D35EBD86DE", "res2048":"...", "residue-type":1, "errors": {"gerbicz":0}, "fft-length":4096, "proof": {"version":1, "power":6, "hashsize":64, "md5":"f663d0abd47a38c98c4486498acf2025"}, "program": {"name":"prmers", "version":"0.1", "port":8, "os": {"os":"Linux", "version":"", "architecture":"x86_64"}}, "user":"cherubrock", "aid":"1EA49D835E08995147899AB4A0E90FF1", "uid":"1EA49D835E08995147899AB4A0E90FF1", "timestamp":"2025-04-21 15:28:12"}
# {"status":"C", "exponent":100049, "worktype":"PRP-3", "res64":"44E92286ACDE5C09", "res2048":"...", "residue-type":1, "errors": {"gerbicz":0}, "fft-length":4096, "proof": {"version":1, "power":6, "hashsize":64, "md5":"fa44a9e853c577a5bf8d539394c01f04"}, "program": {"name":"prmers", "version":"0.1", "port":8, "os": {"os":"Linux", "version":"", "architecture":"x86_64"}}, "user":"cherubrock", "aid":"1EA49D835E08995147899AB4A0E90FF1", "uid":"1EA49D835E08995147899AB4A0E90FF1", "timestamp":"2025-04-21 15:28:20"}
# {"status":"C", "exponent":100057, "worktype":"PRP-3", "res64":"868629ECF6808FF5", "res2048":"...", "residue-type":1, "errors": {"gerbicz":0}, "fft-length":4096, "proof": {"version":1, "power":6, "hashsize":64, "md5":"c629f2efce44f7f924a5ab00aa501976"}, "program": {"name":"prmers", "version":"0.1", "port":8, "os": {"os":"Linux", "version":"", "architecture":"x86_64"}}, "user":"cherubrock", "aid":"1EA49D835E08995147899AB4A0E90FF1", "uid":"1EA49D835E08995147899AB4A0E90FF1", "timestamp":"2025-04-21 15:28:28"}
# {"status":"C", "exponent":100069, "worktype":"PRP-3", "res64":"0EC49AB2F39CBDD2", "res2048":"...", "residue-type":1, "errors": {"gerbicz":0}, "fft-length":4096, "proof": {"version":1, "power":6, "hashsize":64, "md5":"31fab5326f32099e6da4edb1c50f8f85"}, "program": {"name":"prmers", "version":"0.1", "port":8, "os": {"os":"Linux", "version":"", "architecture":"x86_64"}}, "user":"cherubrock", "aid":"1EA49D835E08995147899AB4A0E90FF1", "uid":"1EA49D835E08995147899AB4A0E90FF1", "timestamp":"2025-04-21 15:28:35"}

# %%
#Example with a COMPOSITE mersenne number with asking for primenet submit
# !./prmers 178481
# Out:
# ✅ No valid task found in "worktodo.txt".
# 🧮 Testing exponent: 178481
# Warning: Ignoring unexpected argument '178481'
# PrMers: GPU-accelerated Mersenne primality test (OpenCL, NTT, Lucas-Lehmer)
# Testing exponent: 178481
# Using OpenCL device ID: 0
# Mode selected: PRP
# Backup interval: 120 seconds
# Save/Load path: .
# OpenCL device version detected: 3.0
# Max CL_DEVICE_MAX_WORK_GROUP_SIZE = 1024
# Max CL_DEVICE_MAX_WORK_ITEM_SIZES = 0
# Max CL_DEVICE_LOCAL_MEM_SIZE = 0
# Max max_digit_width for IBDWT = 22
#
# Launching OpenCL kernel (p = 178481); computation may take a while.
# Transform size: 8192
# Final workers count: 8192
# Work-groups count: 256
# Work-groups size: 32
# Workers for carry propagation count: 1024
# Local carry propagation depht: 8
# Local size carry: 256
# Proof Power : 6
# Building OpenCL program with options:  -DWG_SIZE=32 -DLOCAL_PROPAGATION_DEPTH=8 -DCARRY_WORKER=1024 -DLOCAL_PROPAGATION_DEPTH_DIV4=2 -DLOCAL_PROPAGATION_DEPTH_DIV4_MIN=1 -DLOCAL_PROPAGATION_DEPTH_DIV2=2 -DLOCAL_PROPAGATION_DEPTH_DIV2_MIN=3 -DWORKER_NTT=2048 -DWORKER_NTT_2_STEPS=512 -DMODULUS_P=178481 -DTRANSFORM_SIZE_N=8192 -DLOCAL_SIZE=256 -DLOCAL_SIZE2=256 -DLOCAL_SIZE3=256
# Progress: 9.70% | Exponent: 178481 | Iteration: 17319 | Elapsed: 1.00s | Iterations/sec: 17318.95 | ETA: 0d 0h 0m 9s
# Progress: 21.32% | Exponent: 178481 | Iteration: 38060 | Elapsed: 2.00s | Iterations/sec: 19029.44 | ETA: 0d 0h 0m 7s
# Progress: 32.93% | Exponent: 178481 | Iteration: 58765 | Elapsed: 3.00s | Iterations/sec: 19587.55 | ETA: 0d 0h 0m 6s
# Progress: 44.53% | Exponent: 178481 | Iteration: 79474 | Elapsed: 4.00s | Iterations/sec: 19867.63 | ETA: 0d 0h 0m 4s
# Progress: 56.13% | Exponent: 178481 | Iteration: 100179 | Elapsed: 5.00s | Iterations/sec: 20034.80 | ETA: 0d 0h 0m 3s
# Progress: 67.73% | Exponent: 178481 | Iteration: 120878 | Elapsed: 6.00s | Iterations/sec: 20145.27 | ETA: 0d 0h 0m 2s
# Progress: 79.33% | Exponent: 178481 | Iteration: 141586 | Elapsed: 7.00s | Iterations/sec: 20225.44 | ETA: 0d 0h 0m 1s
# Progress: 90.93% | Exponent: 178481 | Iteration: 162294 | Elapsed: 8.00s | Iterations/sec: 20285.57 | ETA: 0d 0h 0m 0s
# Progress: 100.00% | Exponent: 178481 | Iteration: 178481 | Elapsed: 8.78s | Iterations/sec: 20322.08 | ETA: 0d 0h 0m 0s
#
# Kernel execution time: 8.78 seconds
# Iterations per second: 20321.99 (178481 iterations in total)
# Proof generation : Saved partial residue at iteration 2789
# Proof generation : Saved partial residue at iteration 5578
# Proof generation : Saved partial residue at iteration 11156
# Proof generation : Saved partial residue at iteration 22311
# Proof generation : Saved partial residue at iteration 44621
# Proof generation : Saved partial residue at iteration 89241
# Proof saved to ./178481-6.proof
# Proof is saved in a file!
#
#
# ✅ JSON result written to: ./178481_prp_result.json
#
# =============================================
# 🔴 M178481 PRP TEST FAILED
# ❌ RESULT: PROBABLY COMPOSITE (residue is not 9)
# =============================================
# 📦 res64 = 0xE814ACA10504B4A9
# =============================================
#
# ✅ JSON result written to: ./178481_prp_result.json
# Do you want to send the result to PrimeNet (https://www.mersenne.org) ? (y/n): n
# Result not sent.
#
# Press Enter to exit...
